# %%
import pandas as pd

df = pd.read_csv("../data/labeled/dataset.csv")

print(df['label'].value_counts())

print(df.isnull().sum())

df.head(10)
# Out:
# label
# rational_argument         2
# emotional_manipulation    2
# demagogy_tricks           2
# fear_appeal               2
# authority_appeal          2
# Name: count, dtype: int64
# text     0
# label    0
# dtype: int64
#                                                 text                    label
# 0  Уровень безработицы в 2023 году составил 3.2% ...        rational_argument
# 1  Исследование показало, что вакцинация снижает ...        rational_argument
# 2  Ты что, не любишь свою семью? Тогда купи эту с...   emotional_manipulation
# 3  Посмотри на этих несчастных детей — ты обязан ...   emotional_manipulation
# 4                    Кто не с нами — тот против нас.          demagogy_tricks
# 5  Если ты критикуешь власть, значит ты хочешь ха...          demagogy_tricks
# 6  Враги окружают нас со всех сторон и хотят унич...              fear_appeal
# 7  Если мы не примем эти меры — страна погрузится...              fear_appeal
# ...
